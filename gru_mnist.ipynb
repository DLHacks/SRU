# %% [markdown]
# # GRUでMNIST（ベンチマーク）

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_mldata
import numpy as np

import torch
torch.cuda.set_device(2)

# %% [markdown]
# ## 1. MNISTデータセット準備

# %%
def set_data():
    mnist = fetch_mldata('MNIST original')
    mnist_X, mnist_y = shuffle(mnist.data, mnist.target, random_state=42)
    mnist_X = mnist_X / 255.0


    # pytorch用に型変換
    mnist_X, mnist_y = mnist_X.astype('float32'), mnist_y.astype('int64')


    # 2次元の画像を、各行を互い違いにして1次元に変換
    def flatten_img(images):
        '''
        images: shape => (n, rows, columns)
        output: shape => (n, rows*columns)
        '''
        n_rows    = images.shape[1]
        n_columns = images.shape[2]
        for num in range(n_rows):
            if num % 2 != 0:
                images[:, num, :] = images[:, num, :][:, ::-1]
        output = images.reshape(-1, n_rows*n_columns)
        return output

    mnist_X = mnist_X.reshape(-1, 28, 28)
    mnist_X = flatten_img(mnist_X)


    # X.shape => (n_samples, seq_len, n_features) に変換
    mnist_X = mnist_X[:, :, np.newaxis]


    # 訓練、テスト、検証データに分割
    train_X, test_X, train_y, test_y = train_test_split(mnist_X, mnist_y,
                                                        test_size=0.2,
                                                        random_state=42)
    train_X, valid_X, train_y, valid_y = train_test_split(train_X, train_y,
                                                          test_size=0.1,
                                                          random_state=42)

    return train_X, test_X, train_y, test_y, valid_X, valid_y

train_X, test_X, train_y, test_y, valid_X, valid_y = set_data()

# %%
def set_data2():
    mnist = fetch_mldata('MNIST original')
    mnist_X, mnist_y = shuffle(mnist.data, mnist.target, random_state=42)
    mnist_X = mnist_X / 255.0


    # pytorch用に型変換
    mnist_X, mnist_y = mnist_X.astype('float32'), mnist_y.astype('int64')

    mnist_X = mnist_X.reshape(-1, 28, 28)

    # 訓練、テスト、検証データに分割
    train_X, test_X, train_y, test_y = train_test_split(mnist_X, mnist_y,
                                                        test_size=0.2,
                                                        random_state=42)
    train_X, valid_X, train_y, valid_y = train_test_split(train_X, train_y,
                                                          test_size=0.1,
                                                          random_state=42)

    return train_X, test_X, train_y, test_y, valid_X, valid_y

train_X, test_X, train_y, test_y, valid_X, valid_y = set_data2()

# %% [markdown]
# ## 2. モデル構築

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

class GRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, hidden_layers=1, drop_rate=0.6):
        super(GRU, self).__init__()

        self.hidden_size = hidden_size
        self.hidden_layers = hidden_layers

        self.gru = nn.GRU(input_size, hidden_size, num_layers=hidden_layers, dropout=drop_rate)
        self.linear = nn.Linear(hidden_size, output_size)
        self.log_softmax = nn.LogSoftmax()

    def forward(self, inputs, hidden):
        _, self.ht = self.gru(inputs, hidden)
        ## extract the last hidden layer from ht(n_layers, n_samples, hidden_size)
        htL = self.ht[-1]
        outputs = self.linear(htL)
        return outputs

# %% [markdown]
# ## 3. 訓練

# %%
import time
import math
import torch.optim as optim

# 計算時間を表示させる
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


# mini-batchあたりの訓練
def train(model, inputs, labels, optimizer, criterion):
    # 隠れ変数の初期化
    hidden = Variable(torch.randn(
        model.hidden_layers, inputs.size(1), model.hidden_size).cuda())
    # 勾配の初期化
    optimizer.zero_grad()
    outputs = model(inputs, hidden)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    return loss.data[0]


# 検証
def validate(model, inputs, labels, optimizer, criterion):
    # 隠れ変数の初期化
    hidden = Variable(torch.randn(
        model.hidden_layers, inputs.size(1), model.hidden_size).cuda())
    outputs = model(inputs, hidden)
    loss = criterion(outputs, labels)
    return loss.data[0]

# %%
# パラメータの設定
input_size = train_X.shape[2]
hidden_size = 200
output_size = np.unique(train_y).size
drop_rate = 0.5
lr = 0.1

# インスタンスの作成
gru = GRU(input_size, hidden_size, output_size, drop_rate=drop_rate)
gru.cuda()

# loss, optimizerの定義
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(gru.parameters(), lr=lr)

# %%
''' 訓練 '''
n_epochs = 20
batch_size = 300
n_batches = train_X.shape[0]//batch_size
n_batches_v = valid_X.shape[0]//batch_size

start_time = time.time()

for epoch in range(n_epochs):
    train_cost, valid_cost = 0, 0
    
    train_X, train_y = shuffle(train_X, train_y, random_state=42)

    # 訓練
    gru.train()
    train_X_t = np.transpose(train_X, (1, 0, 2)) # X.shape => (seq_len, n_samples, n_features) に変換
    for i in range(n_batches):
        start = i * batch_size
        end = start + batch_size
        inputs, labels = train_X_t[:, start:end, :], train_y[start:end]
        inputs, labels = Variable(torch.from_numpy(inputs).cuda()
                         ), Variable(torch.from_numpy(labels).cuda())
        train_cost += train(gru, inputs, labels, optimizer, criterion) / train_X.shape[0]

    # 検証
    gru.eval()
    valid_X_t = np.transpose(valid_X, (1, 0, 2)) # X.shape => (seq_len, n_samples, n_features) に変換
    for i in range(n_batches_v):
        start = i * batch_size
        end = start + batch_size
        inputs, labels = valid_X_t[:, start:end, :], valid_y[start:end]
        inputs, labels = Variable(torch.from_numpy(inputs).cuda()
                         ), Variable(torch.from_numpy(labels).cuda())
        valid_cost += validate(gru, inputs, labels, optimizer, criterion) / valid_X.shape[0]

    print('EPOCH:: %i, (%s) Training cost: %.5f, Validation cost: %.5f' % (epoch + 1,
                       timeSince(start_time), train_cost, valid_cost))

print('Finished Training')
# Out:
# EPOCH:: 1, (0m 2s) Training cost: 0.00647, Validation cost: 0.00460
# EPOCH:: 2, (0m 4s) Training cost: 0.00387, Validation cost: 0.00319
# EPOCH:: 3, (0m 6s) Training cost: 0.00313, Validation cost: 0.00301
# EPOCH:: 4, (0m 8s) Training cost: 0.00260, Validation cost: 0.00207
# EPOCH:: 5, (0m 11s) Training cost: 0.00199, Validation cost: 0.00159
# EPOCH:: 6, (0m 13s) Training cost: 0.00155, Validation cost: 0.00127
# EPOCH:: 7, (0m 15s) Training cost: 0.00123, Validation cost: 0.00098
# EPOCH:: 8, (0m 17s) Training cost: 0.00100, Validation cost: 0.00091
# EPOCH:: 9, (0m 20s) Training cost: 0.00086, Validation cost: 0.00073
# EPOCH:: 10, (0m 22s) Training cost: 0.00073, Validation cost: 0.00063
# EPOCH:: 11, (0m 24s) Training cost: 0.00065, Validation cost: 0.00054
# EPOCH:: 12, (0m 26s) Training cost: 0.00062, Validation cost: 0.00051
# EPOCH:: 13, (0m 28s) Training cost: 0.00053, Validation cost: 0.00045
# EPOCH:: 14, (0m 31s) Training cost: 0.00049, Validation cost: 0.00042
# EPOCH:: 15, (0m 33s) Training cost: 0.00045, Validation cost: 0.00043
# EPOCH:: 16, (0m 35s) Training cost: 0.00041, Validation cost: 0.00037
# EPOCH:: 17, (0m 37s) Training cost: 0.00039, Validation cost: 0.00044
# EPOCH:: 18, (0m 39s) Training cost: 0.00037, Validation cost: 0.00032
# EPOCH:: 19, (0m 42s) Training cost: 0.00034, Validation cost: 0.00031
# EPOCH:: 20, (0m 44s) Training cost: 0.00032, Validation cost: 0.00026
# Finished Training

# %%
''' テスト '''
test_X_t = np.transpose(test_X[:200], (1, 0, 2))
inputs, labels = test_X_t, test_y[:200]
inputs, labels = Variable(torch.from_numpy(inputs).cuda()
                 ), Variable(torch.from_numpy(labels).cuda())
# 隠れ変数の初期化
hidden = Variable(torch.randn(
    gru.hidden_layers, inputs.size(1), gru.hidden_size).cuda())
# 勾配の初期化
optimizer.zero_grad()
outputs = gru(inputs, hidden)

# 正解数
(torch.max(outputs, 1)[1] == labels).sum()
# Out:
# Variable containing:
#  193
# [torch.cuda.ByteTensor of size 1 (GPU 2)]

# %% [markdown]
# ## 4. ハイパーパラメタのチューニング

# %%
from hyperopt import fmin, tpe, hp, rand

parameter_space = {
	'hidden_size':hp.quniform('hidden_size', 1, 256, q=1),
    'hidden_layers':hp.quniform('hidden_layers', 1, 5, q=1),
	'drop_rate':hp.uniform('drop_rate', 0, 1),
	'lr': hp.loguniform("lr", -10, 0),
}

# %%
# 目的関数
def objective(args):
    print(args)
    hidden_size   = int(args['hidden_size'])
    hidden_layers = int(args['hidden_layers'])
    drop_rate     = args['drop_rate']
    lr            = args['lr']

    train_X, test_X, train_y, test_y, valid_X, valid_y = set_data2()
    input_size = train_X.shape[2]
    output_size = np.unique(train_y).size

    # インスタンスの作成
    gru = GRU(input_size, hidden_size, output_size, hidden_layers, drop_rate=drop_rate)
    gru.cuda()

    # loss, optimizerの定義
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(gru.parameters(), lr=lr)

    n_epochs = 3
    batch_size = 256
    n_batches = train_X.shape[0]//batch_size
    n_batches_v = valid_X.shape[0]//batch_size
    start_time = time.time()

    for epoch in range(n_epochs):
        train_cost, valid_cost = 0, 0

        train_X, train_y = shuffle(train_X, train_y, random_state=42)

        # 訓練
        gru.train()
        train_X_t = np.transpose(train_X, (1, 0, 2)) # X.shape => (seq_len, n_samples, n_features) に変換
        for i in range(n_batches):
            start = i * batch_size
            end = start + batch_size
            inputs, labels = train_X_t[:, start:end, :], train_y[start:end]
            inputs, labels = Variable(torch.from_numpy(inputs).cuda()
                             ), Variable(torch.from_numpy(labels).cuda())
            train_cost += train(gru, inputs, labels, optimizer, criterion) / train_X.shape[0]

    # 検証
    gru.eval()
    valid_X_t = np.transpose(valid_X, (1, 0, 2)) # X.shape => (seq_len, n_samples, n_features) に変換
    for i in range(n_batches_v):
        start = i * batch_size
        end = start + batch_size
        inputs, labels = valid_X_t[:, start:end, :], valid_y[start:end]
        inputs, labels = Variable(torch.from_numpy(inputs).cuda()
                         ), Variable(torch.from_numpy(labels).cuda())
        valid_cost += train(gru, inputs, labels, optimizer, criterion) / valid_X.shape[0]

    # 最後のepochのvalidation_costを返す
    print('(%s) Validation cost: %.7f' % (timeSince(start_time), valid_cost))
    return valid_cost

    del train_X, test_X, train_y, test_y, valid_X, valid_y

# %%
best = fmin(objective, parameter_space, algo=rand.suggest, max_evals=100)
print(best)
# Out:
# {'lr': 0.012006039094902665, 'hidden_size': 138.0, 'hidden_layers': 2.0, 'drop_rate': 0.5227762390918008}
# (0m 9s) Validation cost: 0.0085947
# {'lr': 0.0011715281103349756, 'hidden_size': 243.0, 'hidden_layers': 1.0, 'drop_rate': 0.9441586620847976}
# (0m 7s) Validation cost: 0.0086349
# {'lr': 0.06007910407078869, 'hidden_size': 143.0, 'hidden_layers': 2.0, 'drop_rate': 0.14618554393035188}
# (0m 9s) Validation cost: 0.0059856
# {'lr': 0.12184383541904328, 'hidden_size': 118.0, 'hidden_layers': 5.0, 'drop_rate': 0.31704438123716316}
# (0m 29s) Validation cost: 0.0027788
# {'lr': 0.0006462170286378042, 'hidden_size': 178.0, 'hidden_layers': 4.0, 'drop_rate': 0.10630280784984647}
# (0m 28s) Validation cost: 0.0086363
# {'lr': 0.00038840833399271513, 'hidden_size': 99.0, 'hidden_layers': 4.0, 'drop_rate': 0.1663584234845228}
# (0m 18s) Validation cost: 0.0086320
# {'lr': 0.0034080043851282787, 'hidden_size': 11.0, 'hidden_layers': 2.0, 'drop_rate': 0.13500015329653148}
# (0m 5s) Validation cost: 0.0086397
# {'lr': 0.008351462851247826, 'hidden_size': 107.0, 'hidden_layers': 2.0, 'drop_rate': 0.01428045542033951}
# (0m 8s) Validation cost: 0.0086011
# {'lr': 0.04811077008375372, 'hidden_size': 29.0, 'hidden_layers': 2.0, 'drop_rate': 0.7481453802830113}
# (0m 6s) Validation cost: 0.0078050
# {'lr': 0.20949410419698297, 'hidden_size': 123.0, 'hidden_layers': 3.0, 'drop_rate': 0.2918434561899472}
# (0m 13s) Validation cost: 0.0013118
# {'lr': 0.5951756992501905, 'hidden_size': 112.0, 'hidden_layers': 3.0, 'drop_rate': 0.24022436528350077}
# (0m 12s) Validation cost: 0.0004952
# {'lr': 0.04783872555913615, 'hidden_size': 12.0, 'hidden_layers': 4.0, 'drop_rate': 0.6482152112264434}
# (0m 8s) Validation cost: 0.0084616
# {'lr': 0.001998391249689791, 'hidden_size': 5.0, 'hidden_layers': 1.0, 'drop_rate': 0.4160878805580399}
# (0m 3s) Validation cost: 0.0087177
# {'lr': 0.004580120067905842, 'hidden_size': 192.0, 'hidden_layers': 2.0, 'drop_rate': 0.7603922264795469}
# (0m 11s) Validation cost: 0.0086178
# {'lr': 0.00024178230395600602, 'hidden_size': 148.0, 'hidden_layers': 4.0, 'drop_rate': 0.3453686072633908}
# (0m 24s) Validation cost: 0.0086429
# {'lr': 1.855627804121876, 'hidden_size': 75.0, 'hidden_layers': 3.0, 'drop_rate': 0.7505942495901848}
# (0m 9s) Validation cost: 0.0003753
# {'lr': 0.0808253504677606, 'hidden_size': 128.0, 'hidden_layers': 5.0, 'drop_rate': 0.7995711154926514}
# (0m 30s) Validation cost: 0.0043157
# {'lr': 0.25173895430648296, 'hidden_size': 233.0, 'hidden_layers': 2.0, 'drop_rate': 0.5061973168644311}
# (0m 13s) Validation cost: 0.0010855
# {'lr': 6.367465035581006e-05, 'hidden_size': 161.0, 'hidden_layers': 4.0, 'drop_rate': 0.04004602919827738}
# (0m 26s) Validation cost: 0.0086398
# {'lr': 0.001990541702768098, 'hidden_size': 111.0, 'hidden_layers': 3.0, 'drop_rate': 0.96173194301343}
# (0m 12s) Validation cost: 0.0086292
# {'lr': 0.03540025343862729, 'hidden_size': 54.0, 'hidden_layers': 3.0, 'drop_rate': 0.5850743913599313}
# (0m 8s) Validation cost: 0.0084210
# {'lr': 2.415479712571966, 'hidden_size': 5.0, 'hidden_layers': 3.0, 'drop_rate': 0.3144755429171382}
# (0m 7s) Validation cost: 0.0026442
# {'lr': 0.7160811117754612, 'hidden_size': 101.0, 'hidden_layers': 1.0, 'drop_rate': 0.19913918389285923}
# (0m 5s) Validation cost: 0.0005920
# {'lr': 0.00021848539758811795, 'hidden_size': 20.0, 'hidden_layers': 3.0, 'drop_rate': 0.3357276808969558}
# (0m 7s) Validation cost: 0.0087035
# {'lr': 2.184473331065822, 'hidden_size': 231.0, 'hidden_layers': 4.0, 'drop_rate': 0.25117417917342444}
# (0m 34s) Validation cost: 0.2293775
# {'lr': 2.5788017016485734, 'hidden_size': 47.0, 'hidden_layers': 4.0, 'drop_rate': 0.7409439680331047}
# (0m 10s) Validation cost: 0.0007236
# {'lr': 0.12946126238775787, 'hidden_size': 16.0, 'hidden_layers': 1.0, 'drop_rate': 0.33905946963244393}
# (0m 3s) Validation cost: 0.0049456
# {'lr': 0.6802273928540487, 'hidden_size': 205.0, 'hidden_layers': 4.0, 'drop_rate': 0.41281408032112443}
# (0m 31s) Validation cost: 0.0005168
# {'lr': 2.293757740016408, 'hidden_size': 150.0, 'hidden_layers': 2.0, 'drop_rate': 0.7739078153933419}
# (0m 9s) Validation cost: 0.0100870
# {'lr': 0.0010767832099123204, 'hidden_size': 189.0, 'hidden_layers': 5.0, 'drop_rate': 0.8116607949771064}
# (0m 39s) Validation cost: 0.0086329
# {'lr': 0.015555483086649637, 'hidden_size': 10.0, 'hidden_layers': 3.0, 'drop_rate': 0.153342501107805}
# (0m 7s) Validation cost: 0.0086273
# {'lr': 0.001474775028105657, 'hidden_size': 156.0, 'hidden_layers': 4.0, 'drop_rate': 0.6157811981275046}
# (0m 25s) Validation cost: 0.0086288
# {'lr': 0.013316261319029115, 'hidden_size': 219.0, 'hidden_layers': 3.0, 'drop_rate': 0.19810703398600915}
# (0m 21s) Validation cost: 0.0085887
# {'lr': 0.06618047008117002, 'hidden_size': 182.0, 'hidden_layers': 4.0, 'drop_rate': 0.569127458241545}
# (0m 28s) Validation cost: 0.0039190
# {'lr': 0.02741660440776871, 'hidden_size': 48.0, 'hidden_layers': 5.0, 'drop_rate': 0.5985181002717519}
# (0m 13s) Validation cost: 0.0085754
# {'lr': 0.001977748561726063, 'hidden_size': 154.0, 'hidden_layers': 2.0, 'drop_rate': 0.5263929590577029}
# (0m 9s) Validation cost: 0.0086305
# {'lr': 0.0005798094715874333, 'hidden_size': 123.0, 'hidden_layers': 2.0, 'drop_rate': 0.8439738731568067}
# (0m 8s) Validation cost: 0.0086382
# {'lr': 0.7939869610968481, 'hidden_size': 78.0, 'hidden_layers': 1.0, 'drop_rate': 0.6311008620699559}
# (0m 4s) Validation cost: 0.0004516
# {'lr': 0.8416587274972165, 'hidden_size': 92.0, 'hidden_layers': 3.0, 'drop_rate': 0.15613627227613003}
# (0m 11s) Validation cost: 0.0003633
# {'lr': 0.006320210893757367, 'hidden_size': 222.0, 'hidden_layers': 1.0, 'drop_rate': 0.06785115543855158}
# (0m 7s) Validation cost: 0.0086128
# {'lr': 0.05138533916379463, 'hidden_size': 93.0, 'hidden_layers': 1.0, 'drop_rate': 0.18983332380783757}
# (0m 4s) Validation cost: 0.0082913
# {'lr': 0.0005364499414705012, 'hidden_size': 147.0, 'hidden_layers': 4.0, 'drop_rate': 0.5356762066232935}
# (0m 24s) Validation cost: 0.0086298
# {'lr': 0.0001518083568914761, 'hidden_size': 246.0, 'hidden_layers': 2.0, 'drop_rate': 0.13499025386661845}
# (0m 14s) Validation cost: 0.0086312
# {'lr': 0.6715198117613685, 'hidden_size': 232.0, 'hidden_layers': 4.0, 'drop_rate': 0.24550828886161047}
# (0m 34s) Validation cost: 0.0004547
# {'lr': 5.769119758402305e-05, 'hidden_size': 244.0, 'hidden_layers': 3.0, 'drop_rate': 0.6881912807438961}
# (0m 23s) Validation cost: 0.0086446
# {'lr': 8.38872848806474e-05, 'hidden_size': 46.0, 'hidden_layers': 1.0, 'drop_rate': 0.24033064763732648}
# (0m 4s) Validation cost: 0.0086604
# {'lr': 0.00020097691122571615, 'hidden_size': 242.0, 'hidden_layers': 4.0, 'drop_rate': 0.22196797091217013}
# (0m 35s) Validation cost: 0.0086324
# {'lr': 0.0040413346344676995, 'hidden_size': 140.0, 'hidden_layers': 3.0, 'drop_rate': 0.4371911102780166}
# (0m 14s) Validation cost: 0.0086184
# {'lr': 0.0006171745840277334, 'hidden_size': 54.0, 'hidden_layers': 5.0, 'drop_rate': 0.3609667724453681}
# (0m 14s) Validation cost: 0.0086539
# {'lr': 0.012317592155144559, 'hidden_size': 153.0, 'hidden_layers': 2.0, 'drop_rate': 0.6766935945948956}
# (0m 9s) Validation cost: 0.0085916
# {'lr': 0.06034715103649712, 'hidden_size': 9.0, 'hidden_layers': 3.0, 'drop_rate': 0.8283134671477802}
# (0m 7s) Validation cost: 0.0085935
# {'lr': 0.00012297929747903566, 'hidden_size': 8.0, 'hidden_layers': 4.0, 'drop_rate': 0.12655215791880592}
# (0m 9s) Validation cost: 0.0087260
# {'lr': 7.52218654698822e-05, 'hidden_size': 152.0, 'hidden_layers': 2.0, 'drop_rate': 0.397688202434913}
# (0m 9s) Validation cost: 0.0086377
# {'lr': 0.0500542337963211, 'hidden_size': 113.0, 'hidden_layers': 5.0, 'drop_rate': 0.8794962346221455}
# (0m 28s) Validation cost: 0.0081716
# {'lr': 2.638690499750873, 'hidden_size': 228.0, 'hidden_layers': 3.0, 'drop_rate': 0.6882944071566464}
# (0m 22s) Validation cost: 0.2350174
# {'lr': 0.05055048149563756, 'hidden_size': 53.0, 'hidden_layers': 2.0, 'drop_rate': 0.3500348219011089}
# (0m 6s) Validation cost: 0.0077687
# {'lr': 0.034658301605027725, 'hidden_size': 104.0, 'hidden_layers': 3.0, 'drop_rate': 0.7781371809988966}
# (0m 11s) Validation cost: 0.0083000
# {'lr': 0.03249581647883334, 'hidden_size': 92.0, 'hidden_layers': 2.0, 'drop_rate': 0.9569783146897722}
# (0m 8s) Validation cost: 0.0084477
# {'lr': 0.0007276457888354387, 'hidden_size': 45.0, 'hidden_layers': 2.0, 'drop_rate': 0.05264342187841298}
# (0m 6s) Validation cost: 0.0086393
# {'lr': 0.00047789713266875003, 'hidden_size': 244.0, 'hidden_layers': 2.0, 'drop_rate': 0.19675360688662924}
# (0m 14s) Validation cost: 0.0086337
# {'lr': 0.0010515609729733497, 'hidden_size': 88.0, 'hidden_layers': 4.0, 'drop_rate': 0.3994557894193824}
# (0m 16s) Validation cost: 0.0086401
# {'lr': 1.0721147374301465, 'hidden_size': 163.0, 'hidden_layers': 4.0, 'drop_rate': 0.311273462722372}
# (0m 26s) Validation cost: 0.0270726
# {'lr': 0.0006142400149215317, 'hidden_size': 139.0, 'hidden_layers': 1.0, 'drop_rate': 0.09970694422469706}
# (0m 5s) Validation cost: 0.0086348
# {'lr': 0.008621807522827577, 'hidden_size': 108.0, 'hidden_layers': 2.0, 'drop_rate': 0.9171596251393057}
# (0m 8s) Validation cost: 0.0086140
# {'lr': 0.7191596416598559, 'hidden_size': 228.0, 'hidden_layers': 5.0, 'drop_rate': 0.959293069191341}
# (0m 45s) Validation cost: 0.1041266
# {'lr': 1.2201471597603473, 'hidden_size': 84.0, 'hidden_layers': 3.0, 'drop_rate': 0.5284482964012549}
# (0m 10s) Validation cost: 0.0003421
# {'lr': 0.04376255859813435, 'hidden_size': 199.0, 'hidden_layers': 4.0, 'drop_rate': 0.8330714394888751}
# (0m 30s) Validation cost: 0.0069267
# {'lr': 0.15831538857812033, 'hidden_size': 91.0, 'hidden_layers': 4.0, 'drop_rate': 0.0355308497226301}
# (0m 17s) Validation cost: 0.0019171
# {'lr': 0.0014797546846010792, 'hidden_size': 153.0, 'hidden_layers': 2.0, 'drop_rate': 0.8396760970085603}
# (0m 9s) Validation cost: 0.0086404
# {'lr': 1.1329486728264704, 'hidden_size': 229.0, 'hidden_layers': 2.0, 'drop_rate': 0.7788657517180761}
# (0m 13s) Validation cost: 0.0003503
# {'lr': 0.5286486694640393, 'hidden_size': 42.0, 'hidden_layers': 3.0, 'drop_rate': 0.04097621599809431}
# (0m 8s) Validation cost: 0.0005727
# {'lr': 0.0014157943155711874, 'hidden_size': 172.0, 'hidden_layers': 3.0, 'drop_rate': 0.33481568314284593}
# (0m 17s) Validation cost: 0.0086387
# {'lr': 0.0072651880645305715, 'hidden_size': 178.0, 'hidden_layers': 1.0, 'drop_rate': 0.477845641331628}
# (0m 6s) Validation cost: 0.0086166
# {'lr': 1.122366853468871, 'hidden_size': 19.0, 'hidden_layers': 2.0, 'drop_rate': 0.862785137657436}
# (0m 5s) Validation cost: 0.0012172
# {'lr': 0.00010695386850716631, 'hidden_size': 222.0, 'hidden_layers': 2.0, 'drop_rate': 0.07389632849274497}
# (0m 13s) Validation cost: 0.0086456
# {'lr': 0.00019274773069300415, 'hidden_size': 246.0, 'hidden_layers': 5.0, 'drop_rate': 0.43806676685602364}
# (0m 47s) Validation cost: 0.0086325
# {'lr': 1.1310120813157172, 'hidden_size': 255.0, 'hidden_layers': 1.0, 'drop_rate': 0.3438062670285318}
# (0m 7s) Validation cost: 0.0003816
# {'lr': 1.3463021677525162, 'hidden_size': 97.0, 'hidden_layers': 1.0, 'drop_rate': 0.7306782416601058}
# (0m 4s) Validation cost: 0.0003641
# {'lr': 0.04031202185617639, 'hidden_size': 84.0, 'hidden_layers': 4.0, 'drop_rate': 0.7659380495892005}
# (0m 17s) Validation cost: 0.0084070
# {'lr': 0.06747759146390839, 'hidden_size': 235.0, 'hidden_layers': 4.0, 'drop_rate': 0.48737433100951055}
# (0m 34s) Validation cost: 0.0036370
# {'lr': 0.00030166510749812055, 'hidden_size': 154.0, 'hidden_layers': 2.0, 'drop_rate': 0.19736312277023937}
# (0m 10s) Validation cost: 0.0086420
# {'lr': 0.07212916390825061, 'hidden_size': 242.0, 'hidden_layers': 5.0, 'drop_rate': 0.4496341819275633}
# (0m 46s) Validation cost: 0.0040322
# {'lr': 0.21329410048665745, 'hidden_size': 130.0, 'hidden_layers': 5.0, 'drop_rate': 0.15337578812591168}
# (0m 31s) Validation cost: 0.0013123
# {'lr': 0.010530182941520664, 'hidden_size': 115.0, 'hidden_layers': 2.0, 'drop_rate': 0.23143817059782723}
# (0m 8s) Validation cost: 0.0086050
# {'lr': 0.0033503454970058672, 'hidden_size': 38.0, 'hidden_layers': 4.0, 'drop_rate': 0.7141168622407288}
# (0m 10s) Validation cost: 0.0086345
# {'lr': 0.034896582380075605, 'hidden_size': 141.0, 'hidden_layers': 3.0, 'drop_rate': 0.9205599332176554}
# (0m 14s) Validation cost: 0.0081960
# {'lr': 4.8561461807097e-05, 'hidden_size': 215.0, 'hidden_layers': 5.0, 'drop_rate': 0.36190514438793686}
# (0m 43s) Validation cost: 0.0086456
# {'lr': 0.00012023165409870263, 'hidden_size': 36.0, 'hidden_layers': 3.0, 'drop_rate': 0.35465628184816844}
# (0m 8s) Validation cost: 0.0086845
# {'lr': 0.0003315815969991182, 'hidden_size': 206.0, 'hidden_layers': 2.0, 'drop_rate': 0.7994391015496158}
# (0m 11s) Validation cost: 0.0086433
# {'lr': 0.0006531478276317509, 'hidden_size': 180.0, 'hidden_layers': 2.0, 'drop_rate': 0.1626431097310196}
# (0m 11s) Validation cost: 0.0086329
# {'lr': 0.008563003088756934, 'hidden_size': 235.0, 'hidden_layers': 2.0, 'drop_rate': 0.4483387108256005}
# (0m 13s) Validation cost: 0.0086083
# {'lr': 0.0024407818647539234, 'hidden_size': 87.0, 'hidden_layers': 4.0, 'drop_rate': 0.03243192775210779}
# (0m 15s) Validation cost: 0.0086303
# {'lr': 0.9420691744332402, 'hidden_size': 228.0, 'hidden_layers': 3.0, 'drop_rate': 0.9903202518962163}
# (0m 22s) Validation cost: 0.1637213
# {'lr': 7.379029633149941e-05, 'hidden_size': 128.0, 'hidden_layers': 2.0, 'drop_rate': 0.25490281076644716}
# (0m 8s) Validation cost: 0.0086437
# {'lr': 0.9754776159864449, 'hidden_size': 52.0, 'hidden_layers': 3.0, 'drop_rate': 0.000285915603621234}
# (0m 8s) Validation cost: 0.0003717
# {'lr': 0.042388929847209815, 'hidden_size': 202.0, 'hidden_layers': 2.0, 'drop_rate': 0.6417446323657622}
# (0m 12s) Validation cost: 0.0071634
# {'lr': 5.9497418937572895e-05, 'hidden_size': 29.0, 'hidden_layers': 3.0, 'drop_rate': 0.28935374101219125}
# (0m 8s) Validation cost: 0.0086651
# {'lr': 0.007054244377707208, 'hidden_size': 6.0, 'hidden_layers': 2.0, 'drop_rate': 0.7169676002785464}
# (0m 5s) Validation cost: 0.0086676
# {'lr': 0.2755023969414207, 'hidden_size': 13.0, 'hidden_layers': 4.0, 'drop_rate': 0.197241538913019}
# (0m 8s) Validation cost: 0.0029783
# {'lr': 6.540788242164408e-05, 'hidden_size': 235.0, 'hidden_layers': 3.0, 'drop_rate': 0.12742246853141104}
# (0m 23s) Validation cost: 0.0086431
# {'lr': 1.2201471597603473, 'hidden_size': 84.0, 'hidden_layers': 3.0, 'drop_rate': 0.5284482964012549}
